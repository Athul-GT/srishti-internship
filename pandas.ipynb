# %%
import pandas as pd
data={'Name':['Alice','bob'],'age':[20,23]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  age
# 0  Alice   20
# 1    bob   23

# %%
df.iloc[1]
# Out:
# Name    bob
# age      23
# Name: 1, dtype: object

# %%
df.loc[0]
# Out:
# Name    Alice
# age        20
# Name: 0, dtype: object

# %%
df[df['age']<=20]
# Out:
#     Name  age
# 0  Alice   20

# %%
df['city']=['Tvm','banglr']
print(df)
# Out:
#     Name  age    city
# 0  Alice   20     Tvm
# 1    bob   23  banglr

# %%
df
# Out:
#     Name  age    city
# 0  Alice   20     Tvm
# 1    bob   23  banglr

# %%
new_rows=[
    ['Abel',21,'ptna'],
    ['Adhil',23,'ermli']
]
for row in new_rows:
    df.loc[len(df)] = row
df
# Out:
#     Name  age    city
# 0  Alice   20     Tvm
# 1    bob   23  banglr
# 2   Abel   21    ptna
# 3  Adhil   23   ermli

# %%
df.groupby('city')['age'].mean()
# Out:
# city
# Tvm       20.0
# banglr    23.0
# ermli     23.0
# ptna      21.0
# Name: age, dtype: float64
